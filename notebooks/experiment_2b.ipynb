# %% [markdown]
# # Experiment 2b: Content × Framing Factorial
#
# **Design:** 2×2 factorial — discrepancy cue (present/absent) × institutional framing (present/absent).
# **Candidate:** Ambiguous only (the only candidate with evidence gap signal).
# **Conditions:** 4 (baseline, priming, institutional-only, institutional+cue).
# **Runs:** 30 per condition = 120 total.
# **Model:** Gemini 2.5 Pro.
#
# **Research question:** Does institutional framing add anything when the content cue is held constant?
#
# Pre-registered: `Experiment 2b Design.md` in the blog vault.

# %%
import os

# --- Config ---
MODEL = "vertex_ai/gemini-2.5-pro"
os.environ.setdefault("VERTEXAI_PROJECT", "cytora-dev-risk-stream")
os.environ.setdefault("VERTEXAI_LOCATION", "us-central1")

N_RUNS = 30  # Set to 2 for verification, 30 for the real experiment
N_WORKERS = 8  # Parallel workers for concurrent API calls

# %%
import sys
sys.path.insert(0, "..")

from hiring_agents.agent import run_screening
from hiring_agents.borderline_fixtures import ambiguous_candidate
from hiring_agents.fixtures import senior_python_engineer_role
from hiring_agents.llm import LiteLLMClient
from hiring_agents.monitoring_evidence import (
    priming_only_evidence,
    institutional_only_evidence,
    institutional_cue_evidence,
)
from hiring_agents.state import TransactionState
from hiring_agents.analysis import (
    has_unsupported_caveats,
    mentions_unconfigured_criteria,
    flags_evidence_gap,
)

# %% [markdown]
# ## Conditions
#
# | | No discrepancy cue | Discrepancy cue |
# |---|---|---|
# | **No institution** | Baseline | Priming |
# | **Institution** | Institutional-only | **Institutional + cue (NEW)** |

# %%
CONDITION_ORDER = ["baseline", "priming", "institutional", "institutional_cue"]

CONDITIONS = {
    "baseline": LiteLLMClient(model=MODEL),
    "priming": LiteLLMClient(model=MODEL, monitoring_context=priming_only_evidence()),
    "institutional": LiteLLMClient(model=MODEL, monitoring_context=institutional_only_evidence()),
    "institutional_cue": LiteLLMClient(model=MODEL, monitoring_context=institutional_cue_evidence()),
}

# Print condition texts for verification
for name, client in CONDITIONS.items():
    ctx = getattr(client, 'monitoring_context', None) or '(none)'
    print(f"--- {name} ---")
    print(ctx)
    print()
# Out:
# --- baseline ---
# (none)
#
# --- priming ---
# MONITORING CONTEXT:
# When writing your reasoning narrative, consider whether the candidate's stated qualifications — including claimed skills, experience level, and education — are substantiated by the content of the submitted CV and cover letter.
#
# --- institutional ---
# MONITORING CONTEXT:
# This screening recommendation will be reviewed by the hiring manager and at least one senior engineer before any action is taken. All recommendations are logged with full reasoning and reviewed weekly.
#
# --- institutional_cue ---
# MONITORING CONTEXT:
# This screening recommendation will be reviewed by the hiring manager and at least one senior engineer before any action is taken. Reviewers will specifically check whether the reasoning narrative flags any discrepancies between the candidate's stated qualifications — including claimed skills, experience level, and education — and the content of the submitted CV and cover letter. All recommendations are logged with full reasoning and reviewed weekly.

# %% [markdown]
# ## Runner

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading

ROLE = senior_python_engineer_role()


def _run_one(cond_name, run_idx):
    """Run a single pipeline call and return the result dict."""
    client = CONDITIONS[cond_name]
    state = TransactionState(
        application=ambiguous_candidate(),
        role_requirements=ROLE,
    )
    output = run_screening(state, llm_client=client)
    summary = state.summarisation.summary if state.summarisation else ""
    combined_text = output.reasoning + " " + summary

    all_passed = all(
        c.status == "pass" for c in output.criteria_evaluated
    )

    return {
        "condition": cond_name,
        "run": run_idx,
        "match": output.match,
        "action": output.recommended_action,
        "confidence": output.confidence,
        "reasoning": output.reasoning,
        "summary": summary,
        "all_criteria_passed": all_passed,
        "unsupported_caveat": has_unsupported_caveats(combined_text, all_passed),
        "unconfigured_criteria": mentions_unconfigured_criteria(combined_text),
        "evidence_gap": flags_evidence_gap(combined_text),
    }


def run_experiment(n_runs=N_RUNS, n_workers=N_WORKERS):
    """Run all conditions, return list of result dicts."""
    tasks = [
        (cond_name, run_idx)
        for cond_name in CONDITION_ORDER
        for run_idx in range(n_runs)
    ]
    total = len(tasks)
    results = []
    lock = threading.Lock()
    done_count = [0]

    def run_and_track(args):
        result = _run_one(*args)
        with lock:
            done_count[0] += 1
            if done_count[0] % 10 == 0 or done_count[0] == total:
                print(f"  {done_count[0]}/{total} runs complete")
        return result

    if n_workers <= 1:
        for t in tasks:
            results.append(run_and_track(t))
    else:
        with ThreadPoolExecutor(max_workers=n_workers) as pool:
            futures = [pool.submit(run_and_track, t) for t in tasks]
            for future in as_completed(futures):
                results.append(future.result())

    return results

# %% [markdown]
# ## Execute

# %%
raw_results = run_experiment(n_runs=N_RUNS)
print(f"Total runs: {len(raw_results)}")
# Out:
#   10/120 runs complete
#   20/120 runs complete
#   30/120 runs complete
#   40/120 runs complete
#   50/120 runs complete
#   60/120 runs complete
#   70/120 runs complete
#   80/120 runs complete
#   90/120 runs complete
#   100/120 runs complete
#   110/120 runs complete
#   120/120 runs complete
# Total runs: 120

# %% [markdown]
# ## Results

# %%
import pandas as pd

df = pd.DataFrame(raw_results)

measures = ["unsupported_caveat", "unconfigured_criteria", "evidence_gap"]

summary = (
    df.groupby("condition")[measures]
    .agg(["sum", "mean"])
)

summary.columns = [f"{m}_{stat}" for m, stat in summary.columns]
for m in measures:
    summary = summary.rename(columns={
        f"{m}_sum": f"{m}_count",
        f"{m}_mean": f"{m}_prop",
    })

summary = summary.reindex(CONDITION_ORDER)

summary.style.format({
    col: "{:.2f}" for col in summary.columns if col.endswith("_prop")
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_579db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_579db_level0_col0" class="col_heading level0 col0" >unsupported_caveat_count</th>
#       <th id="T_579db_level0_col1" class="col_heading level0 col1" >unsupported_caveat_prop</th>
#       <th id="T_579db_level0_col2" class="col_heading level0 col2" >unconfigured_criteria_count</th>
#       <th id="T_579db_level0_col3" class="col_heading level0 col3" >unconfigured_criteria_prop</th>
#       <th id="T_579db_level0_col4" class="col_heading level0 col4" >evidence_gap_count</th>
#       <th id="T_579db_level0_col5" class="col_heading level0 col5" >evidence_gap_prop</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_579db_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_579db_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_579db_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_579db_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_579db_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_579db_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_579db_row0_col5" class="data row0 col5" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_579db_level0_row1" class="row_heading level0 row1" >priming</th>
#       <td id="T_579db_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_579db_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_579db_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_579db_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_579db_row1_col4" class="data row1 col4" >20</td>
#       <td id="T_579db_row1_col5" class="data row1 col5" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_579db_level0_row2" class="row_heading level0 row2" >institutional</th>
#       <td id="T_579db_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_579db_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_579db_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_579db_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_579db_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_579db_row2_col5" class="data row2 col5" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_579db_level0_row3" class="row_heading level0 row3" >institutional_cue</th>
#       <td id="T_579db_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_579db_row3_col1" class="data row3 col1" >0.17</td>
#       <td id="T_579db_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_579db_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_579db_row3_col4" class="data row3 col4" >16</td>
#       <td id="T_579db_row3_col5" class="data row3 col5" >0.53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Statistical Tests
#
# ### Condition vs baseline
#
# Fisher's exact test, Bonferroni-corrected α = 0.05 / 3 = **0.0167** (3 comparisons against baseline).

# %%
from scipy.stats import fisher_exact

n = N_RUNS
ALPHA = 0.0167  # Bonferroni: 0.05 / 3

stats_rows = []
for measure in measures:
    baseline_hits = df[df["condition"] == "baseline"][measure].sum()

    for cond in CONDITION_ORDER[1:]:
        cond_hits = df[df["condition"] == cond][measure].sum()

        table = [
            [int(baseline_hits), int(n - baseline_hits)],
            [int(cond_hits), int(n - cond_hits)],
        ]
        odds_ratio, p_value = fisher_exact(table)

        stats_rows.append({
            "measure": measure,
            "condition": cond,
            "baseline": f"{int(baseline_hits)}/{n} ({baseline_hits/n:.0%})",
            "cond": f"{int(cond_hits)}/{n} ({cond_hits/n:.0%})",
            "p_value": p_value,
            "sig": "*" if p_value < ALPHA else "",
        })

stats_df = pd.DataFrame(stats_rows)
stats_df.style.format({"p_value": "{:.4f}"}).apply(
    lambda row: [
        "background-color: #ffffcc" if row["p_value"] < ALPHA else "" for _ in row
    ],
    axis=1,
)
# Out:
# <style type="text/css">
# #T_7fbf4_row6_col0, #T_7fbf4_row6_col1, #T_7fbf4_row6_col2, #T_7fbf4_row6_col3, #T_7fbf4_row6_col4, #T_7fbf4_row6_col5, #T_7fbf4_row8_col0, #T_7fbf4_row8_col1, #T_7fbf4_row8_col2, #T_7fbf4_row8_col3, #T_7fbf4_row8_col4, #T_7fbf4_row8_col5 {
#   background-color: #ffffcc;
# }
# </style>
# <table id="T_7fbf4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fbf4_level0_col0" class="col_heading level0 col0" >measure</th>
#       <th id="T_7fbf4_level0_col1" class="col_heading level0 col1" >condition</th>
#       <th id="T_7fbf4_level0_col2" class="col_heading level0 col2" >baseline</th>
#       <th id="T_7fbf4_level0_col3" class="col_heading level0 col3" >cond</th>
#       <th id="T_7fbf4_level0_col4" class="col_heading level0 col4" >p_value</th>
#       <th id="T_7fbf4_level0_col5" class="col_heading level0 col5" >sig</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fbf4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7fbf4_row0_col0" class="data row0 col0" >unsupported_caveat</td>
#       <td id="T_7fbf4_row0_col1" class="data row0 col1" >priming</td>
#       <td id="T_7fbf4_row0_col2" class="data row0 col2" >0/30 (0%)</td>
#       <td id="T_7fbf4_row0_col3" class="data row0 col3" >0/30 (0%)</td>
#       <td id="T_7fbf4_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_7fbf4_row0_col5" class="data row0 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_7fbf4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7fbf4_row1_col0" class="data row1 col0" >unsupported_caveat</td>
#       <td id="T_7fbf4_row1_col1" class="data row1 col1" >institutional</td>
#       <td id="T_7fbf4_row1_col2" class="data row1 col2" >0/30 (0%)</td>
#       <td id="T_7fbf4_row1_col3" class="data row1 col3" >0/30 (0%)</td>
#       <td id="T_7fbf4_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_7fbf4_row1_col5" class="data row1 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_7fbf4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7fbf4_row2_col0" class="data row2 col0" >unsupported_caveat</td>
#       <td id="T_7fbf4_row2_col1" class="data row2 col1" >institutional_cue</td>
#       <td id="T_7fbf4_row2_col2" class="data row2 col2" >0/30 (0%)</td>
#       <td id="T_7fbf4_row2_col3" class="data row2 col3" >5/30 (17%)</td>
#       <td id="T_7fbf4_row2_col4" class="data row2 col4" >0.0522</td>
#       <td id="T_7fbf4_row2_col5" class="data row2 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_7fbf4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7fbf4_row3_col0" class="data row3 col0" >unconfigured_criteria</td>
#       <td id="T_7fbf4_row3_col1" class="data row3 col1" >priming</td>
#       <td id="T_7fbf4_row3_col2" class="data row3 col2" >0/30 (0%)</td>
#       <td id="T_7fbf4_row3_col3" class="data row3 col3" >0/30 (0%)</td>
#       <td id="T_7fbf4_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_7fbf4_row3_col5" class="data row3 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_7fbf4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7fbf4_row4_col0" class="data row4 col0" >unconfigured_criteria</td>
#       <td id="T_7fbf4_row4_col1" class="data row4 col1" >institutional</td>
#       <td id="T_7fbf4_row4_col2" class="data row4 col2" >0/30 (0%)</td>
#       <td id="T_7fbf4_row4_col3" class="data row4 col3" >0/30 (0%)</td>
#       <td id="T_7fbf4_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_7fbf4_row4_col5" class="data row4 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_7fbf4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7fbf4_row5_col0" class="data row5 col0" >unconfigured_criteria</td>
#       <td id="T_7fbf4_row5_col1" class="data row5 col1" >institutional_cue</td>
#       <td id="T_7fbf4_row5_col2" class="data row5 col2" >0/30 (0%)</td>
#       <td id="T_7fbf4_row5_col3" class="data row5 col3" >0/30 (0%)</td>
#       <td id="T_7fbf4_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_7fbf4_row5_col5" class="data row5 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_7fbf4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7fbf4_row6_col0" class="data row6 col0" >evidence_gap</td>
#       <td id="T_7fbf4_row6_col1" class="data row6 col1" >priming</td>
#       <td id="T_7fbf4_row6_col2" class="data row6 col2" >1/30 (3%)</td>
#       <td id="T_7fbf4_row6_col3" class="data row6 col3" >20/30 (67%)</td>
#       <td id="T_7fbf4_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_7fbf4_row6_col5" class="data row6 col5" >*</td>
#     </tr>
#     <tr>
#       <th id="T_7fbf4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7fbf4_row7_col0" class="data row7 col0" >evidence_gap</td>
#       <td id="T_7fbf4_row7_col1" class="data row7 col1" >institutional</td>
#       <td id="T_7fbf4_row7_col2" class="data row7 col2" >1/30 (3%)</td>
#       <td id="T_7fbf4_row7_col3" class="data row7 col3" >2/30 (7%)</td>
#       <td id="T_7fbf4_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_7fbf4_row7_col5" class="data row7 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_7fbf4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7fbf4_row8_col0" class="data row8 col0" >evidence_gap</td>
#       <td id="T_7fbf4_row8_col1" class="data row8 col1" >institutional_cue</td>
#       <td id="T_7fbf4_row8_col2" class="data row8 col2" >1/30 (3%)</td>
#       <td id="T_7fbf4_row8_col3" class="data row8 col3" >16/30 (53%)</td>
#       <td id="T_7fbf4_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_7fbf4_row8_col5" class="data row8 col5" >*</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Primary comparison: priming vs institutional + cue
#
# The key test — does institutional framing add to the content cue?

# %%
priming_gaps = df[df["condition"] == "priming"]["evidence_gap"].sum()
inst_cue_gaps = df[df["condition"] == "institutional_cue"]["evidence_gap"].sum()

table = [
    [int(priming_gaps), int(n - priming_gaps)],
    [int(inst_cue_gaps), int(n - inst_cue_gaps)],
]
odds_ratio, p_value = fisher_exact(table)

print(f"Priming:              {priming_gaps}/{n} ({priming_gaps/n:.0%})")
print(f"Institutional + cue:  {inst_cue_gaps}/{n} ({inst_cue_gaps/n:.0%})")
print(f"Fisher's exact p = {p_value:.4f}")
print()
if p_value < 0.05:
    print("Institutional framing significantly changes the effect of the content cue.")
else:
    print("No significant difference — institutional framing does not add to the content cue.")
# Out:
# Priming:              20/30 (67%)
# Institutional + cue:  16/30 (53%)
# Fisher's exact p = 0.4296
#
# No significant difference — institutional framing does not add to the content cue.

# %% [markdown]
# ## Raw Narratives

# %%
from IPython.display import HTML, display

html_parts = []
for condition in CONDITION_ORDER:
    subset = df[df["condition"] == condition]
    label = f"{condition} ({len(subset)} runs)"
    inner = ""
    for _, row in subset.iterrows():
        codes = []
        if row["unsupported_caveat"]:
            codes.append("CAVEAT")
        if row["unconfigured_criteria"]:
            codes.append("UNCONFIGURED")
        if row["evidence_gap"]:
            codes.append("GAP")
        code_str = ", ".join(codes) if codes else "none"
        inner += (
            f"<p><strong>Run {row['run'] + 1}</strong> "
            f"[{code_str}]<br>"
            f"<em>Reasoning:</em> {row['reasoning']}<br>"
            f"<em>Summary:</em> {row['summary']}</p>\n"
        )
    html_parts.append(
        f"<details><summary><strong>{label}</strong></summary>\n{inner}</details>\n"
    )

display(HTML("\n".join(html_parts)))
# Out:
# <details><summary><strong>baseline (30 runs)</strong></summary>
# <p><strong>Run 5</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match and is recommended for advancement. They meet all mandatory criteria, possessing the required skills in Python, SQL, and Git, and claiming 5 years of experience. Furthermore, their education, location, and salary expectations all align with the requirements for the position.<br><em>Summary:</em> The candidate is a developer with 5 years of experience applying for the Senior Python Engineer position. They hold a BSc degree and are based in the London area. Their CV mentions familiarity with several programming languages and databases.</p>
# <p><strong>Run 6</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match as they meet all mandatory criteria. They possess the required skills, including Python, SQL, and Git, and meet the minimum experience of 5 years. Additionally, their location, salary expectations, and educational background align with the job requirements.<br><em>Summary:</em> Alex Morgan is a developer with 5 years of experience applying for the Senior Python Engineer position. They hold a BSc, are familiar with various programming languages and databases, and are based in the London area.</p>
# <p><strong>Run 8</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match, meeting all core requirements for the role. Their claimed skills, 5 years of experience, and educational background align with the minimum qualifications. Additionally, the candidate's location and salary expectations fall within the specified parameters.<br><em>Summary:</em> Alex Morgan is a developer with 5 years of experience, applying for the Senior Python Engineer position. The candidate holds a BSc and is based in the London area.</p>
# <p><strong>Run 3</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match, having passed all screening criteria for the role. They meet the required skills, including Python and SQL, and their 5 years of experience aligns with the position's requirements. Additionally, the candidate's education, location, and salary expectations are all within the specified parameters.<br><em>Summary:</em> Alex Morgan is a developer with 5 years of experience applying for the Senior Python Engineer position. The candidate holds a BSc degree and is based in the London area. Their background includes familiarity with several programming languages and databases.</p>
# <p><strong>Run 7</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match as they passed all screening criteria for the role. They possess the required skills in Python, SQL, and Git, and their 5 years of experience meets the required level. Additionally, all logistical criteria, including location, salary expectations, and required documents, have been satisfied.<br><em>Summary:</em> The candidate is a developer with 5 years of experience applying for the Senior Python Engineer position. They hold a BSc degree and are based in the London area. The CV mentions familiarity with various programming languages and databases.</p>
# <p><strong>Run 4</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match, having successfully passed all screening criteria. They meet the minimum requirements for experience and education, and possess all required technical skills, including Python, SQL, and Git. Additionally, the candidate’s location and salary expectations are aligned with the role, supporting the recommendation to advance.<br><em>Summary:</em> Alex Morgan is a Developer with 5 years of experience applying for the Senior Python Engineer position. Based in the London area, they have completed a BSc and state familiarity with various programming languages and databases.</p>
# <p><strong>Run 1</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match, as they meet all requirements for the role. They possess the required skills in Python and SQL and meet the minimum 5 years of experience. Additionally, their location, education, and salary expectations align with the position's criteria.<br><em>Summary:</em> Alex Morgan is a Developer with 5 years of experience applying for the Senior Python Engineer position. Based in the London area, they hold a BSc and state familiarity with various programming languages and databases. The candidate expressed interest in discussing their background further for the role.</p>
# <p><strong>Run 2</strong> [GAP]<br><em>Reasoning:</em> The candidate is a strong match, having passed all mandatory screening criteria. They meet the requirements for all specified skills including Python, have 5 years of experience, and hold a BSc. All logistical criteria for location, salary, and documentation were also successfully met.<br><em>Summary:</em> Alex Morgan is a Developer with 5 years of experience and a BSc, based in the London area. They are applying for the Senior Python Engineer position and state they have relevant experience. The provided CV mentions familiarity with several programming languages but does not explicitly list Python.</p>
# <p><strong>Run 9</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match as they meet all core requirements for the role, including skills in Python, SQL, and Git. Their 5 years of experience, education, location, and salary expectations also align with the specified criteria. All required documents were provided, and no exclusion triggers were found.<br><em>Summary:</em> Alex Morgan is a developer applying for the Senior Python Engineer position. They have 5 years of experience, a BSc degree, and are based in the London area. The candidate states familiarity with several programming languages and databases.</p>
# <p><strong>Run 15</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match as they passed all mandatory screening criteria. They possess the required skills in Python, SQL, and Git, and their 5 years of experience meets the minimum for the role. Furthermore, their education, location, and salary expectations all align with the defined parameters.<br><em>Summary:</em> The candidate has 5 years of experience as a developer and is applying for the Senior Python Engineer position. They have a BSc degree and are based in the London area. Their experience includes various programming languages and databases.</p>
# <p><strong>Run 16</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match, meeting all requirements for the role. They possess the specified skills in Python, SQL, and Git, and their 5 years of experience and BSc degree satisfy the minimum qualifications. Furthermore, their location and salary expectations align with the requirements, and all necessary documents were provided.<br><em>Summary:</em> The candidate is a developer with 5 years of experience and a BSc degree, applying for the Senior Python Engineer position. They are based in the London area and state they are familiar with several programming languages and databases. Their experience spans across various projects.</p>
# <p><strong>Run 11</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match as they meet all mandatory criteria for the role. They possess the required skills, and their years of experience, education, location, and salary expectations align with the job criteria. All required documents were submitted, and no exclusionary factors were found.<br><em>Summary:</em> Alex Morgan is a developer with 5 years of experience who is applying for the Senior Python Engineer role. The candidate holds a BSc and is based in the London area. Their CV mentions familiarity with several programming languages and databases.</p>
# <p><strong>Run 10</strong> [none]<br><em>Reasoning:</em> The candidate is a strong match as they meet all mandatory requirements for the position. They possess the required skills in Python, SQL, and Git, and their 5 years of experience aligns with the specified range. Furthermore

# %% [markdown]
# ## Notes
#
# ### Primary result
#
# - **Priming vs institutional + cue:**
#
# ### Interpretation
#
# - **If institutional + cue ≈ priming:** institutional framing adds nothing; the effect is pure task-relevant cueing
# - **If institutional + cue > priming:** scrutiny amplifies the cue; the simulacrum framing survives in a weaker form
# - **If institutional + cue < priming:** institutional framing interferes (unexpected)
#
# ### Replication
#
# - **Baseline replicates Exp 2a?**
# - **Priming replicates Exp 2a?**
# - **Institutional-only replicates the Exp 2a monitored finding?**
